# %% [markdown]
# ### Initialise

# %%
## Import necessary packages
import matplotlib.pyplot as plt; 
import pandas as pd; 
import numpy as np; 
import json; 
# from datetime import datetime; 

from sklearn.model_selection import train_test_split;
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

import python.data as datameta

# %%
def mse(a,b): return (mean_squared_error(a,b)); 
def mae(a,b): return (mean_absolute_error(a,b)); 
def r2(a,b): return (r2_score(a,b)**0.5); 
def isClose(base, known, tol=0.001): return np.abs((base - known) / base) <= tol; 
def pct(val): return str(val*100)[:5]+"%"; 

def row(name,ytest, yhat, accuracies):
    return [
        name, 
        r2(ytest, yhat),mae(ytest, yhat),mse(ytest, yhat), 
        accuracies[0], accuracies[1], accuracies[2]
    ]; 

def accuracy(test,pred,tol): 
    checks = np.isclose(test,pred, rtol=tol); 
    acc = np.sum(checks)/len(checks); 
    
    return pct(acc);

# %% [markdown]
# ### Preprocess Data

# %%
data = datameta.processData('data/ashwin_data.csv'); 
data = data[5:]; 
data.head()
# Out:
# Index(['Time (h)_mean', 'Aeration rate(Fg:L/h)_mean',
#        'Sugar feed rate(Fs:L/h)_mean', 'Acid flow rate(Fa:L/h)_mean',
#        'Base flow rate(Fb:L/h)_mean', 'Air head pressure(pressure:bar)_mean',
#        'Substrate concentration(S:g/L)_mean', 'Vessel Volume(V:L)_mean',
#        'pH(pH:pH)_mean', 'Temperature(T:K)_mean',
#        'PAA flow(Fpaa:PAA flow (L/h))_mean', 'Oil flow(Foil:L/hr)_mean',
#        'Ammonia shots(NH3_shots:kgs)_mean', 'Water Flow_mean', 'Time (h)_std',
#        'Aeration rate(Fg:L/h)_std', 'Sugar feed rate(Fs:L/h)_std',
#        'Acid flow rate(Fa:L/h)_std', 'Base flow rate(Fb:L/h)_std',
#        'Air head pressure(pressure:bar)_std',
#        'Substrate concentration(S:g/L)_std', 'Vessel Volume(V:L)_std',
#        'pH(pH:pH)_std', 'Temperature(T:K)_std',
#        'PAA flow(Fpaa:PAA flow (L/h))_std', 'Oil flow(Foil:L/hr)_std',
#        'Ammonia shots(NH3_shots:kgs)_std', 'Water Flow_std', 'Time (h)_max',
#        'Aeration rate(Fg:L/h)_max', 'Sugar feed rate(Fs:L/h)_max',
#        'Acid flow rate(Fa:L/h)_max', 'Base flow rate(Fb:L/h)_max',
#        'Air head pressure(pressure:bar)_max',
#        'Substrate concentration(S:g/L)_max', 'Vessel Volume(V:L)_max',
#        'pH(pH:pH)_max', 'Temperature(T:K)_max',
#        'PAA flow(Fpaa:PAA flow (L/h))_max', 'Oil flow(Foil:L/hr)_max',
#        'Ammonia shots(NH3_shots:kgs)_max', 'Water Flow_max', 'Time (h)_min',
#        'Aeration rate(Fg:L/h)_min', 'Sugar feed rate(Fs:L/h)_min',
#        'Acid flow rate(Fa:L/h)_min', 'Base flow rate(Fb:L/h)_min',
#        'Air head pressure(pressure:bar)_min',
#        'Substrate concentration(S:g/L)_min', 'Vessel Volume(V:L)_min',
#        'pH(pH:pH)_min', 'Temperature(T:K)_min',
#        'PAA flow(Fpaa:PAA flow (L/h))_min', 'Oil flow(Foil:L/hr)_min',
#        'Ammonia shots(NH3_shots:kgs)_min', 'Water Flow_min',
#        'Penicillin concentration(P:g/L)'],
#       dtype='object')
#
#  (113930, 57)
#    Time (h)_mean  Aeration rate(Fg:L/h)_mean  Sugar feed rate(Fs:L/h)_mean  \
# 5      -1.686999                   -3.024788                      -2.69834
# 6      -1.684007                   -3.024788                      -2.69834
# 7      -1.681015                   -3.024788                      -2.69834
# 8      -1.678022                   -3.024788                      -2.69834
# 9      -1.675030                   -3.024788                      -2.69834
#
#    Acid flow rate(Fa:L/h)_mean  Base flow rate(Fb:L/h)_mean  \
# 5                    -0.140341                    -1.326449
# 6                    -0.140341                    -1.190789
# 7                    -0.140341                    -0.980954
# 8                    -0.140341                    -0.792846
# 9                    -0.140341                    -0.715976
#
#    Air head pressure(pressure:bar)_mean  Substrate concentration(S:g/L)_mean  \
# 5                             -2.575004                            -0.207601
# 6                             -2.575004                            -0.205311
# 7                             -2.575004                            -0.203198
# 8                             -2.575004                            -0.201274
# 9                             -2.575004                            -0.199540
#
#    Vessel Volume(V:L)_mean  pH(pH:pH)_mean  Temperature(T:K)_mean  ...  \
# 5                -1.725402       -0.134967               0.153442  ...
# 6                -1.725519       -0.286846               0.134358  ...
# 7                -1.725402       -0.250542               0.134358  ...
# 8                -1.725131       -0.060309               0.134358  ...
# 9                -1.724782        0.179520               0.134358  ...
#
#    Air head pressure(pressure:bar)_min  Substrate concentration(S:g/L)_min  \
# 5                            -2.551834                           -0.207984
# 6                            -2.551834                           -0.205513
# 7                            -2.551834                           -0.203209
# 8                            -2.551834                           -0.201087
# 9                            -2.551834                           -0.199153
#
#    Vessel Volume(V:L)_min  pH(pH:pH)_min  Temperature(T:K)_min  \
# 5               -1.715376      -0.267401               0.48637
# 6               -1.715376      -0.267401               0.48637
# 7               -1.715376      -0.267401               0.48637
# 8               -1.715259      -0.212237               0.48637
# 9               -1.714910       0.019145               0.48637
#
#    PAA flow(Fpaa:PAA flow (L/h))_min  Oil flow(Foil:L/hr)_min  \
# 5                           -0.72962                -0.875667
# 6                           -0.72962                -0.875667
# 7                           -0.72962                -0.875667
# 8                           -0.72962                -0.875667
# 9                           -0.72962                -0.875667
#
#    Ammonia shots(NH3_shots:kgs)_min  Water Flow_min  \
# 5                               0.0       -1.401446
# 6                               0.0       -1.398315
# 7                               0.0       -1.391404
# 8                               0.0       -1.381575
# 9                               0.0       -1.369507
#
#    Penicillin concentration(P:g/L)
# 5                        -1.443146
# 6                        -1.443146
# 7                        -1.443146
# 8                        -1.443146
# 9                        -1.443146
#
# [5 rows x 57 columns]

# %%
# Split into x and y
# xkeys = [
#     "Time (h)", "Aeration rate(Fg:L/h)", "Sugar feed rate(Fs:L/h)","Acid flow rate(Fa:L/h)",
#     "Base flow rate(Fb:L/h)","Water Flow","Substrate concentration(S:g/L)","PAA flow(Fpaa:PAA flow (L/h))",
#     "Oil flow(Foil:L/hr)", "Ammonia shots(NH3_shots:kgs)",
#     # Converted variables
#     "Air head pressure(pressure:bar)", "Temperature(T:K)", "pH(pH:pH)", "Vessel Volume(V:L)"
# ]
ykeys = ["Penicillin concentration(P:g/L)"]; 
(x,y) = datameta.xy_split_y(data,ykeys); 
xtrain, xtest, ytrain, ytest=train_test_split(x, y, test_size=0.11); 
# ytest = ytest.to_numpy().flatten(); 


xtrain_mean = np.mean(xtrain, axis=0); 
xtrain_std = np.std(xtrain, axis=0) +1e-29; 

ytrain_mean = np.mean(ytrain, axis=0); 
ytrain_std = np.std(ytrain, axis=0) +1e-29; 

print(
    xtrain.shape,
    xtrain_mean.shape,
    xtrain_std.shape
)

print(
    ytrain.shape,
    ytrain_mean.shape,
    ytrain_std.shape
)

ytrain_mean = ytrain_mean.values.reshape(1,-1); 
xtrain_mean = xtrain_mean.values.reshape(1,-1); 
ytrain_std = ytrain_std.values.reshape(1,-1); 
xtrain_std = xtrain_std.values.reshape(1,-1); 

xtrain, xtest = (xtrain - xtrain_mean)/xtrain_std, (xtest - xtrain_mean)/xtrain_std; 
ytrain, ytest = (ytrain - ytrain_mean)/ytrain_std, (ytest - ytrain_mean)/ytrain_std; 

# SETUP ENDS HERE
# Out:
# x:  56  keys in  56 cols
# y:  1  keys in  1 cols
# (101393, 56) (56,) (56,)
# (101393, 1) (1,) (1,)

# %%
model = DecisionTreeRegressor(); 
model.fit(xtrain,ytrain); 

print(
    f"Train: {pct(model.score(xtrain,ytrain))}\n",
    f"Test: {pct(model.score(xtest,ytest))}"
)
# Out:
# Train: 99.99%
#  Test: 99.53%

# %%
prediction= pd.DataFrame(model.predict(xtest));  
plt.scatter(ytest,prediction); 

print(ytest.shape, prediction.shape); 
print(accuracy(ytest, prediction, 0.001));
# Out:
# (12532, 1) (12532, 1)
# 18.47%

# %%
parameters={
    "splitter":["best","random"],
    "max_depth" : [i for i in range(10,15)],
    "min_samples_leaf":[i for i in range(4,11)],
    "min_weight_fraction_leaf":[0.0, 0.1],
    "max_leaf_nodes":[i*10 for i in range(6,12)]
}

# %%
from sklearn.model_selection import GridSearchCV; 

tuning_model=GridSearchCV(model,param_grid=parameters,scoring='neg_root_mean_squared_error',cv=3, n_jobs=-1,verbose=2)

tuning_model.fit(x, y)
# Out:
# Fitting 3 folds for each of 840 candidates, totalling 2520 fits
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.8s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.2s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.2s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.0s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.0s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=60, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.0s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=70, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=80, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.0s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=90, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.5s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=10, max_leaf_nodes=100, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.1s
# ...
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=100, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=4, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=5, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=6, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.3s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.0s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=7, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=8, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.7s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.2s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=9, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=random; total time=   0.1s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.1, splitter=best; total time=   0.6s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.4s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.5s
# [CV] END max_depth=14, max_leaf_nodes=110, min_samples_leaf=10, min_weight_fraction_leaf=0.0, splitter=best; total time=   1.2s
# GridSearchCV(cv=3, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [10, 11, 12, 13, 14],
#                          'max_leaf_nodes': [60, 70, 80, 90, 100, 110],
#                          'min_samples_leaf': [4, 5, 6, 7, 8, 9, 10],
#                          'min_weight_fraction_leaf': [0.0, 0.1],
#                          'splitter': ['best', 'random']},
#              scoring='neg_root_mean_squared_error', verbose=2)

# %%
print(tuning_model)
print("BEST: ",tuning_model.best_params_, tuning_model.best_score_)
results = pd.DataFrame(tuning_model.cv_results_)
results.sort_values(by='rank_test_score', inplace=True)
configs = results[:15]["params"].to_numpy().tolist()
configs = json.dumps(configs)
print(configs)

file = open("data/dtr_cfgs.json", "w+")
content = str(configs)
file.write(content)
file.close()
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [10, 11, 12, 13, 14],
#                          'max_leaf_nodes': [60, 70, 80, 90, 100, 110],
#                          'min_samples_leaf': [4, 5, 6, 7, 8, 9, 10],
#                          'min_weight_fraction_leaf': [0.0, 0.1],
#                          'splitter': ['best', 'random']},
#              scoring='neg_root_mean_squared_error', verbose=2)
# BEST:  {'max_depth': 14, 'max_leaf_nodes': 90, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'} -0.17095832595143975
# [{"max_depth": 14, "max_leaf_nodes": 90, "min_samples_leaf": 6, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 14, "max_leaf_nodes": 80, "min_samples_leaf": 7, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 14, "max_leaf_nodes": 80, "min_samples_leaf": 9, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 11, "max_leaf_nodes": 100, "min_samples_leaf": 10, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 13, "max_leaf_nodes": 110, "min_samples_leaf": 5, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 12, "max_leaf_nodes": 90, "min_samples_leaf": 7, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 13, "max_leaf_nodes": 110, "min_samples_leaf": 6, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 14, "max_leaf_nodes": 100, "min_samples_leaf": 4, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 10, "max_leaf_nodes": 90, "min_samples_leaf": 4, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 11, "max_leaf_nodes": 110, "min_samples_leaf": 9, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 14, "max_leaf_nodes": 100, "min_samples_leaf": 9, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 13, "max_leaf_nodes": 80, "min_samples_leaf": 9, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 10, "max_leaf_nodes": 90, "min_samples_leaf": 5, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 12, "max_leaf_nodes": 100, "min_samples_leaf": 6, "min_weight_fraction_leaf": 0.0, "splitter": "random"}, {"max_depth": 13, "max_leaf_nodes": 80, "min_samples_leaf": 4, "min_weight_fraction_leaf": 0.0, "splitter": "random"}]

# %%
# RUN FROM HERE
file = open("data/dtr_cfgs.json", "r")
content = file.read()
file.close()
configs = json.loads(content); 

for dict in configs:
    for key,value in enumerate(dict):
        if value=="null": 
            dict[key] = None;

# %%
table = [0 for _ in range(len(configs))]

# configs.append({})
for index,config in enumerate(configs):
    print(f"Running: {config}")
    tmodel = DecisionTreeRegressor(**config); 
    tmodel.fit(xtrain,ytrain); 

    yhat = pd.DataFrame(tmodel.predict(xtest))

    accuracies = list(map(
        lambda x: accuracy(yhat, ytest, x)
    ,[0.005, 0.01, 0.1])) 
    print(
        ytest.shape,    
        yhat.shape
    )

    table[index] = row(json.dumps(config), ytest, yhat, accuracies)

table = pd.DataFrame(table, columns=["","R2","MAE", "MSE","Acc@0.1%", "Acc@1%", "Acc@10%"]); 
table
# Out:
# Running: {'max_depth': 14, 'max_leaf_nodes': 90, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 14, 'max_leaf_nodes': 80, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 14, 'max_leaf_nodes': 80, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 11, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 13, 'max_leaf_nodes': 110, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 12, 'max_leaf_nodes': 90, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 13, 'max_leaf_nodes': 110, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 14, 'max_leaf_nodes': 100, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 10, 'max_leaf_nodes': 90, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 11, 'max_leaf_nodes': 110, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 14, 'max_leaf_nodes': 100, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 13, 'max_leaf_nodes': 80, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 10, 'max_leaf_nodes': 90, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 12, 'max_leaf_nodes': 100, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
# Running: {'max_depth': 13, 'max_leaf_nodes': 80, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.0, 'splitter': 'random'}
# (12532, 1) (12532, 1)
#                                                              R2       MAE  \
# 0   {"max_depth": 14, "max_leaf_nodes": 90, "min_s...  0.990389  0.095738
# 1   {"max_depth": 14, "max_leaf_nodes": 80, "min_s...  0.990598  0.098026
# 2   {"max_depth": 14, "max_leaf_nodes": 80, "min_s...  0.990960  0.097011
# 3   {"max_depth": 11, "max_leaf_nodes": 100, "min_...  0.991633  0.092980
# 4   {"max_depth": 13, "max_leaf_nodes": 110, "min_...  0.991696  0.091953
# 5   {"max_depth": 12, "max_leaf_nodes": 90, "min_s...  0.990963  0.096643
# 6   {"max_depth": 13, "max_leaf_nodes": 110, "min_...  0.991772  0.091410
# 7   {"max_depth": 14, "max_leaf_nodes": 100, "min_...  0.991393  0.093420
# 8   {"max_depth": 10, "max_leaf_nodes": 90, "min_s...  0.990628  0.097894
# 9   {"max_depth": 11, "max_leaf_nodes": 110, "min_...  0.991540  0.091624
# 10  {"max_depth": 14, "max_leaf_nodes": 100, "min_...  0.991397  0.093907
# 11  {"max_depth": 13, "max_leaf_nodes": 80, "min_s...  0.990629  0.097086
# 12  {"max_depth": 10, "max_leaf_nodes": 90, "min_s...  0.990995  0.096171
# 13  {"max_depth": 12, "max_leaf_nodes": 100, "min_...  0.991671  0.092119
# 14  {"max_depth": 13, "max_leaf_nodes": 80, "min_s...  0.990454  0.098036
#
#          MSE Acc@0.1%   Acc@1%  Acc@10%
# 0   0.019469  13.90%%  17.27%%  51.65%%
# 1   0.019047  13.73%%  16.59%%  50.98%%
# 2   0.018316  3.016%%  15.69%%  51.86%%
# 3   0.016959  3.239%%  16.93%%  52.60%%
# 4   0.016832  5.146%%  16.86%%  52.97%%
# 5   0.018310  3.016%%  16.15%%  52.21%%
# 6   0.016678  3.662%%  17.47%%  52.99%%
# 7   0.017444  13.61%%  16.60%%  52.00%%
# 8   0.018986  5.082%%  16.83%%  50.87%%
# 9   0.017146  13.95%%  17.82%%  52.66%%
# 10  0.017436  5.473%%  17.06%%  52.47%%
# 11  0.018985  13.32%%  16.26%%  51.27%%
# 12  0.018247  5.202%%  16.63%%  51.30%%
# 13  0.016883  13.74%%  16.74%%  52.93%%
# 14  0.019338  4.907%%  16.25%%  52.17%%

# %%
table = [0]

model = DecisionTreeRegressor(); 
model.fit(xtrain,ytrain); 

yhat = pd.DataFrame(model.predict(xtest))

accuracies = list(map(
    lambda x: accuracy(yhat, ytest, x)
,[0.001, 0.01, 0.1])) 
print(f"Accuracies: {accuracies}")
table[0] = row(json.dumps(config), ytest , model.predict(xtest), accuracies)
# Out:
# Accuracies: ['18.48%', '62.63%', '87.13%']

# %%
print(xtrain.keys())
plt.hist(xtrain["Vessel Volume(V:L)"], bins=100)
# Out:
# Index(['PAA flow(Fpaa:PAA flow (L/h))_min', 'Temperature(T:K)_max',
#        'Aeration rate(Fg:L/h)_std', 'Substrate concentration(S:g/L)_std',
#        'Sugar feed rate(Fs:L/h)_mean', 'PAA flow(Fpaa:PAA flow (L/h))_max',
#        'Water Flow_mean', 'Base flow rate(Fb:L/h)_mean',
#        'Oil flow(Foil:L/hr)_min', 'Air head pressure(pressure:bar)_min',
#        'Aeration rate(Fg:L/h)_min', 'Time (h)_std', 'Time (h)_min',
#        'pH(pH:pH)_min', 'Air head pressure(pressure:bar)_mean',
#        'Air head pressure(pressure:bar)_max', 'Vessel Volume(V:L)_mean',
#        'Temperature(T:K)_mean', 'Water Flow_max',
#        'PAA flow(Fpaa:PAA flow (L/h))_mean',
#        'Air head pressure(pressure:bar)_std', 'Oil flow(Foil:L/hr)_std',
#        'Ammonia shots(NH3_shots:kgs)_std', 'Sugar feed rate(Fs:L/h)_std',
#        'Acid flow rate(Fa:L/h)_mean', 'Oil flow(Foil:L/hr)_max',
#        'Acid flow rate(Fa:L/h)_std', 'Aeration rate(Fg:L/h)_max',
#        'Time (h)_max', 'Vessel Volume(V:L)_max', 'Base flow rate(Fb:L/h)_min',
#        'Temperature(T:K)_min', 'Ammonia shots(NH3_shots:kgs)_mean',
#        'pH(pH:pH)_max', 'pH(pH:pH)_mean', 'PAA flow(Fpaa:PAA flow (L/h))_std',
#        'Water Flow_std', 'Substrate concentration(S:g/L)_min', 'pH(pH:pH)_std',
#        'Acid flow rate(Fa:L/h)_max', 'Substrate concentration(S:g/L)_max',
#        'Base flow rate(Fb:L/h)_std', 'Time (h)_mean', 'Vessel Volume(V:L)_min',
#        'Oil flow(Foil:L/hr)_mean', 'Temperature(T:K)_std',
#        'Substrate concentration(S:g/L)_mean', 'Acid flow rate(Fa:L/h)_min',
#        'Sugar feed rate(Fs:L/h)_max', 'Ammonia shots(NH3_shots:kgs)_min',
#        'Vessel Volume(V:L)_std', 'Water Flow_min',
#        'Base flow rate(Fb:L/h)_max', 'Aeration rate(Fg:L/h)_mean',
#        'Ammonia shots(NH3_shots:kgs)_max', 'Sugar feed rate(Fs:L/h)_min'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Vessel Volume(V:L)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [13], line 2
#       1 print(xtrain.keys())
# ----> 2 plt.hist(xtrain["Vessel Volume(V:L)"], bins=100)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Vessel Volume(V:L)'

# %%
plt.hist(yhat, bins=100)

# %%
plt.hist(ytest, bins=100)
